# %% [markdown]
# # CHANGE DATA FEED

# %%
# %sql
ALTER TABLE deltalakesharnam.default.clonetbl
SET TBLPROPERTIES (delta.enableChangeDataFeed = true)

# %%
# %sql
SeLECT * FROM deltalakesharnam.default.clonetbl

# %%
# %sql
INSERT INTO deltalakesharnam.default.clonetbl
VALUES (10,100,'zz','1')

# %%
# %sql
UPDATE deltalakesharnam.default.clonetbl
SET name = 'hi bro' where cust_id = 10

# %%
# %sql
DELETE FROM deltalakesharnam.default.clonetbl
WHERE cust_id=3

# %%
# %sql
DESCRIBE HISTORY deltalakesharnam.default.clonetbl

# %%
# %sql
SELECT * FROM table_changes('deltalakesharnam.default.clonetbl',1)
