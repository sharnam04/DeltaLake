# %% [markdown]
# # TABLE UTILITY COMMANDS

# %% [markdown]
# ### DETAIL/EXTENDED

# %%
# %sql
DESCRIBE deltalakesharnam.default.employee

# %%
# %sql
DESCRIBE DETAIL deltalakesharnam.default.employee

# %%
# %sql
DESCRIBE EXTENDED deltalakesharnam.default.employee

# %% [markdown]
# ### DATA VERSIONING

# %%
# %sql
DESCRIBE HISTORY delta.`/Volumes/deltalakesharnam/default/deltavol/dmlsink/`

# %%
# %sql
RESTORE TABLE delta.`/Volumes/deltalakesharnam/default/deltavol/dmlsink/` 
TO VERSION AS OF 3

# %%
# %sql
SELECT * FROM delta.`/Volumes/deltalakesharnam/default/deltavol/dmlsink/`

# %%
# %sql
SELECT * FROM delta.`/Volumes/deltalakesharnam/default/deltavol/dmlsink/` 
VERSION AS OF 1

# %%
# %sql
SELECT * FROM delta.`/Volumes/deltalakesharnam/default/deltavol/dmlsink/` 
TIMESTAMP AS OF '2026-07-04T08:56:24.000+00:00'

# %%
# %sql
SHOW TBLPROPERTIES deltalakesharnam.default.employee

# %%
# %sql
SHOW TBLPROPERTIES delta.`/Volumes/deltalakesharnam/default/deltavol/dmlsink/`

# %% [markdown]
# ### VACUUM

# %%
# %sql
VACUUM delta.`/Volumes/deltalakesharnam/default/deltavol/dmlsink/`
-- RETAIN 0 HOURS

# %% [markdown]
# ### CLONE

# %%
# %sql
CREATE TABLE deltalakesharnam.default.clonetbl
CLONE delta.`/Volumes/deltalakesharnam/default/deltavol/dmlsink/` VERSION AS OF 3

# %%
# %sql
SELECT * FROM deltalakesharnam.default.clonetbl
